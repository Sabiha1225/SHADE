# %% [markdown]
# TreeCNN in nilmtk measurements

# %%
# With redd dataset building 6 (training), 5 (testing)
#import numpy as np
#import matplotlib.pyplot as plt

#categories = ['FHMM', 'CO', 'TreeCNN', 'Seq2Point']
#X = ['fridge','dishwasher','washer-dryer']
#data = [82.54,  9.94, 2.93]
#val = [97.62, 10.65, 0.26]
#r = [78.28, 10.54, 1.68]
#seq = [41.59, 10.51, 2.62]

#X_axis = np.arange(len(X))

#fig = plt.figure(figsize = (5, 2.5))
#plt.rcParams['font.size'] = '8'
#plt.bar(X_axis - 0.266, data, 0.266, color ='#0789BE', label = 'FHMM')
#plt.bar(X_axis + 0.0, val, 0.266, color ='#958C05', label = 'CO')
#plt.bar(X_axis + 0.266, r, 0.266, color ='#0DBFCE', label = 'TreeCNN')

#plt.xticks(X_axis, X)
#plt.xlabel("Appliances")
#plt.ylabel("MAE")
#plt.title("Redd Dataset")
#plt.legend()
#plt.show()

# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

#species = ('FHMM', 'CO', 'TreeCNN', 'Seq2Point')
species = ('10','25','50', '75')
colors = ["#76c8c8", "#de6e56"]
hatches = ["\\", "/", "*", "x"]
penguin_means = {
    'With PADS': (26.27,  33.11, 85.06, 98.42),
    'Without PADS': (22.13, 31.46, 62.61, 82.61),
}

x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

#fig, ax = plt.subplots(layout='constrained')
fig, ax = plt.subplots()

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, hatch=hatches[multiplier], color=colors[multiplier])
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hit Rate', fontsize=8)
ax.set_xlabel("Cache Sizes (% of WSS)", fontsize=8)
ax.set_title('Alexnet (CIFAR10 Dataset)', fontsize=8)
ax.set_xticks(x + width, species, fontsize=8)
ax.legend(loc='upper left', fontsize=8)
fig.set_size_inches(4,4)
ax.tick_params(axis='y', labelsize=8)
#plt.rc('font', size=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

#species = ('FHMM', 'CO', 'TreeCNN', 'Seq2Point')
species = ('10','25','50', '75')
colors = ["#76c8c8", "#de6e56", "#958C05"]
hatches = ["\\", "/", "*", "x"]
penguin_means = {
    'sh_RAND': (20.55, 35.54, 65.01, 88.39),
    'sh_LFU': (18.25, 35.36, 63.36, 88.11),
    'sh_APP': (24.45, 49.68, 90.24, 96.39)
}

x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

#fig, ax = plt.subplots(layout='constrained')
fig, ax = plt.subplots()

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, hatch=hatches[multiplier], color=colors[multiplier])
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hit Rate', fontsize=8)
ax.set_xlabel("Cache Sizes (% of WSS)", fontsize=8)
ax.set_title('CIFAR-10 Dataset', fontsize=8)
ax.set_xticks(x+width, species, fontsize=8)
ax.legend(loc='upper left', fontsize=8)
fig.set_size_inches(4,4)
ax.tick_params(axis='y', labelsize=8)
#plt.rc('font', size=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

#species = ('FHMM', 'CO', 'TreeCNN', 'Seq2Point')
species = ('10','25','50', '75')
colors = ["#76c8c8", "#de6e56", "#958C05", "#A58EA8"]
hatches = ["\\", "/", "*", "x"]
penguin_means = {
    'CIFAR-10': (26.27,  33.11, 85.06, 98.42),
    #'sh_lfu_CIFAR-10': (16.59,  36.63, 63.25, 87.98),
    'MNIST': (26.25, 54.45, 93.04, 99.99),
    #'sh_lfu_MNIST': (26.25, 54.45, 93.04, 99.99),
}

x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

#fig, ax = plt.subplots(layout='constrained')
fig, ax = plt.subplots()

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, hatch=hatches[multiplier], color=colors[multiplier])
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hit Rate', fontsize=8)
ax.set_xlabel("Cache Sizes (% of WSS)", fontsize=8)
ax.set_title('Alexnet', fontsize=8)
ax.set_xticks(x + width, species, fontsize=8)
ax.legend(loc='upper left', fontsize=8)
fig.set_size_inches(4,4)
ax.tick_params(axis='y', labelsize=8)
#plt.rc('font', size=12)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

#species = ('FHMM', 'CO', 'TreeCNN', 'Seq2Point')
species = ('32','64','128', '256')
colors = ["#de6e56", "#958C05", "#958C05", "#A58EA8"]
hatches = ["\\", "*", "*", "x"]
penguin_means = {
    'sh_app': (92.73,  92.76, 92.69, 92.73),
    'sh_lfu': (63.59, 63.42, 65.56, 64.51)
}

x = np.arange(len(species))  # the label locations
width = 0.15  # the width of the bars
multiplier = 0

#fig, ax = plt.subplots(layout='constrained')
fig, ax = plt.subplots()

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, hatch=hatches[multiplier], color=colors[multiplier])
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hit Rate', fontsize=8)
#ax.xlabel("Appliances")
ax.set_title('AlexNet (CIFAR-10 Dataset)', fontsize=8)
ax.set_xticks(x + width, species, fontsize=8)
ax.set_xlabel('Batch Size', fontsize=8)
ax.legend(loc='upper left', fontsize=8)
fig.set_size_inches(4,4)
ax.tick_params(axis='y', labelsize=8)
#plt.rc('font', size=12)
plt.show()

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np

# create data
x = [170,300,480,650,800]
y1 = [10.58,10.81,10.02,17.04,19.69]
y2 = [12.67,28.23,38.13,51.42,55.81]
y3 = [10,14.76,18.93,27.33,38.86]
y4 = [10,12.34,11.45,18.66,30.58]
y5 = [10,10.57,10,10,10.13]
y6 = [12.96,20.91,10,16.05,10]
y7 = [9.99,18.88,10,10,10]
y8 = [10,10.45,10,10,10]

# plot lines
plt.plot(x, y1, label = "sh_APP 10%", color='#234F1E')
plt.plot(x, y2, label = "sh_APP 25%", color='#98BF64')
plt.plot(x, y3, label = "sh_APP 50%", color='#FA8128')
plt.plot(x, y4, label = "sh_APP 75%", color='#710193')
plt.plot(x, y5, label = "sh_LFU 10%", linestyle='dashed', color='#BF4F51', marker='x', markerfacecolor='#C60C30', markersize=5)
plt.plot(x, y6, label = "sh_LFU 25%", linestyle='dashed', color='#710C04', marker='+', markerfacecolor='#420C09', markersize=5)
plt.plot(x, y7, label = "sh_LFU 50%", linestyle='dashed', color='#E3242B', marker='*', markerfacecolor='#900D09', markersize=5)
plt.plot(x, y8, label = "sh_LFU 75%", linestyle='dashed', color='#0066B2', marker='o', markerfacecolor='blue', markersize=5)
plt.legend()
plt.ylabel("Accuracy (Percent)")
plt.xlabel("Time (Sec)")
plt.title("AlexNet (CIFAR-10 Dataset)")
plt.show()
